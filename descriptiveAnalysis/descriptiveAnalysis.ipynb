# %%
import numpy as np
import pandas as pd

# %%
csv_file = "../dataset/med_data.csv"
df = pd.read_csv(csv_file, encoding='cp1252')

# %%
df
# Out:
#       FinancialYear                                        Description  \
# 0         2017-2018                     650LITERFUELTANKFORINCINERATOR
# 1         2017-2018                BIOLABOEXATROL-N(NORMALLEVEL)10X5ML
# 2         2017-2018                                    MAGNESIUM8*10ML
# 3         2017-2018             HDL-CHOLESTEROLDIRECTMETHOD200-250TEST
# 4         2017-2018                BIOLABOEXATROL-N(NORMALLEVEL)10X5ML
# 5         2017-2018          BIOLABOEXATROL-P(PATHOLOGICALLEVEL)10X5ML
# 6         2017-2018                             HDL/LDLCALIBRATOR2X2ML
# 7         2017-2018               HDL/LDL/CK-MBCONTROLSERALEVEL1-2X2ML
# 8         2017-2018               HDL/LDL/CK-MBCONTROLSERALEVEL2-2X2ML
# 9         2017-2018                            REAGENTBOTTLECAP(WHITE)
# 10        2017-2018                              REAGENTBOTTLECAP(RED)
# 11        2017-2018                                     GAMMAGT10X10ML
# ...

# %%
df.CustomerName.value_counts()
# Out:
# PROVINCIALDIRECTOROFHEALTHSERVICES-KURUNEGALA                      1015
# TEACHINGHOSPITAL-KANDY                                              626
# TEACHINGHOSPITAL-COLOMBOSOUTH                                       575
# SRIJAYAWARDENAPURAGENERALHOSPITAL-NUGEGODA                          566
# SIRIMAVOBANDARANAYAKEPEADIATRICHOSPITAL-PERADENIYA                  520
# TEACHINGHOSPITAL-KARAPITIYA                                         515
# GENERALHOSPITAL-BADULLA                                             442
# NATIONALHOSPITALOFSRILANKA                                          433
# TEACHINGHOSPITAL-COLOMBONORTH                                       424
# GENERALHOSPITAL-POLONNARUWA                                         419
# TEACHINGHOSPITAL-KURUNEGALA                                         419
# REGIONALDIRECTOROFHEALTHSERVICES-KEGALLE                            416
# REGIONALDIRECTOROFHEALTHSERVICES-JAFFNA                             334
# ...

# %%
a = df.groupby(['CustomerName'])['Quantity'].sum()
b =df.groupby(['CustomerName'])['CustomerName'].count()
(a/b)
# Out:
# CustomerName
# ANTI-LEPROSYCAMPAIGN-MOH                                              1.000000
# ASHRAFFMEMORIALHOSPITAL                                               4.080645
# BASEHOSPITAL(TEACHING)-GAMPOLA                                        6.500000
# BASEHOSPITAL-AKKARAIPATTU                                             4.528662
# BASEHOSPITAL-AVISSAWELLA                                           1607.652778
# BASEHOSPITAL-BALAPITIYA                                               8.252336
# BASEHOSPITAL-DAMBADENIYA                                              1.200000
# BASEHOSPITAL-DAMBULLA                                                 1.142857
# BASEHOSPITAL-DENIYAYA                                                 1.000000
# BASEHOSPITAL-DIYATALAWA                                               8.647619
# BASEHOSPITAL-ELPITIYA                                                 1.090909
# BASEHOSPITAL-GALGAMUWA                                                1.333333
# ...

# %%
df.groupby(['CustomerName'])['CustomerName'].count()
# Out:
# CustomerName
# ANTI-LEPROSYCAMPAIGN-MOH                                             1
# ASHRAFFMEMORIALHOSPITAL                                            248
# BASEHOSPITAL(TEACHING)-GAMPOLA                                      22
# BASEHOSPITAL-AKKARAIPATTU                                          157
# BASEHOSPITAL-AVISSAWELLA                                            72
# BASEHOSPITAL-BALAPITIYA                                            214
# BASEHOSPITAL-DAMBADENIYA                                             5
# BASEHOSPITAL-DAMBULLA                                                7
# BASEHOSPITAL-DENIYAYA                                                1
# BASEHOSPITAL-DIYATALAWA                                            105
# BASEHOSPITAL-ELPITIYA                                               11
# BASEHOSPITAL-GALGAMUWA                                               3
# BASEHOSPITAL-HOMAGAMA                                              215
# ...

# %%
a = df.groupby(['Description'])['Quantity'].sum()
b =df.groupby(['Description'])['CustomerName'].count()
(a/b)
# Out:
# Description
# (S)-(+)-2-PHENYLBUTYRICACID99%,1G                                      4.000000
# *HICROMEEBSLAGARBASE                                                   2.000000
# -40°CDEEPFREEZER                                                       1.000000
# -86°CULTRA-LOWTEMPERATUREFREEZER(MINUS80CDEEPFREEZER)                  1.000000
# 01KVAOFFLINEUPS                                                        4.000000
# 01KVAONLINEUPS                                                         1.666667
# 06KVAISOLATION                                                         1.000000
# 1"FILTERMPVAUTO                                                        2.000000
# 1000ULFILTERTIP,RACK,STERILE,96TIPS/RACK                              20.000000
# 1000VA/700WISOLATION                                                   1.888889
# 1000µLPIPETTETIPS,STERILE,96PCS/RACK                                  30.000000
# 1059                                                                  70.000000
# ...

# %%
df.Supplier.value_counts()
# Out:
# SHENZHENMINDRAYBIO-MEDICALELECTRONICSCO.,LTD    8288
# BIOLABOSAS                                      3058
# THERMOELECTRONOY                                2810
# BIOMERIEUXSA                                    1214
# DIAMONDDIAGNOSTICSINC.                           360
# PARCTECHNOLOGIQUELEONARDDEVINCI(SEBIA)           316
# SHENZHENCAREWELLELECTRONICSCO.,LTD.              181
# VACUTESTKIMAS.R.L.                               129
# TECOMEDICALINSTRUMENTSGMBH                       120
# GEMMYINDUSTRIALCORP.                             108
# ANALYTICALINSTRUMENTS(PVT)LTD                    102
# ASSIDUATECHNOLOGIES(PVT)LTD                       89
# DIRUIINDUSTRIALCO.,LTD.                           88
# REMIELEKTROTECHNIKLTD.                            80
# VARIOUSPLACES                                     80
# LOCALPURCHASE-MR.WEERAWARNE                       62
# BIOMEDICA(PVT)LTD                                 59
# LOCALPURCHASE-                                    58
# ...

# %%
df.ProductGroup.value_counts()
# Out:
# BIOCHEMISTRY                   10128
# HEMATOLOGY                      5078
# IMMUNOLOGY                       756
# MICROBIOLOGY                     509
# GENERALLABORATORY                426
# OTHER                            285
# HDU                              199
# COAGULATION                      182
# GENERAL                          163
# HISTOPATHOLOGY                   107
# URINE                             70
# MICROSCOPE                        17
# PROJECTS                          14
# CHEMICALS&CONSUMABLES              3
# LABORATORYINFORMATIONSYSTEM        1
# Name: ProductGroup, dtype: int64

# %%
df.Region.value_counts()
# Out:
# MED-REGION04    3101
# MED-REGION02    2893
# MED-REGION06    2624
# MED-REGION03    2179
# MED-REGION09    1762
# MED-REGION01    1697
# MED-REGION07     906
# MED-REGION05     782
# MED-REGION11     704
# MED-REGION10     593
# MED-REGION08     536
# REGION00         161
# Name: Region, dtype: int64

# %%
df.CusType.value_counts()
# Out:
# GVT    17938
# Name: CusType, dtype: int64

# %%
df['Town'] = df['CustomerName'].str.split('-', 1).str[1]
df.Town.value_counts()
# Out:
# KURUNEGALA                          1434
# PERADENIYA                           831
# KEGALLE                              698
# KANDY                                668
# BADULLA                              631
# COLOMBOSOUTH                         575
# NUGEGODA                             566
# KARAPITIYA                           515
# RATHNAPURA                           512
# JAFFNA                               484
# MATARA                               479
# POLONNARUWA                          432
# COLOMBONORTH                         424
# HAMBANTOTA                           395
# GAMPAHA                              357
# KALUTARA                             350
# BATTICALOA                           303
# ANURADHAPURA                         301
# NEGOMBO                              297
# MATALE                               289
# NUWARAELIYA                          273
# GALLE                                269
# COLOMBO10                            266
# ...

# %%
dfMED_REGION04 = df[df['Region'] == 'MED-REGION04']
dfMED_REGION04.Town.value_counts()
# Out:
# PERADENIYA           830
# KEGALLE              698
# KANDY                662
# MATALE               289
# NUWARAELIYA          273
# NAWALAPITIYA         259
# COLOMBO03             36
# GAMPOLA               22
# DIGANA                20
# DAMBULLA               7
# KARAWANELLA.           2
# PHARMACOLOGY           1
# FACULTYOFMEDICINE      1
# WARAKAPOLA             1
# Name: Town, dtype: int64

# %%
dfMED_REGION05 = df[df['Region'] == 'MED-REGION05']
dfMED_REGION05.Town.value_counts()
# Out:
# POLONNARUWA             428
# ANURADHAPURA            296
# RATHMALGAHAWEWA          20
# NORTHCENTRALPROVINC,     17
# WELIKANDA                12
# HOROWPATHANA              5
# MEDIRIGIRIYA              3
# ANURADAPURA               1
# Name: Town, dtype: int64

# %%
dfMED_REGION01 = df[df['Region'] == 'MED-REGION01']
dfMED_REGION01.Town.value_counts()
# Out:
# KURUNEGALA      1434
# CHILAW           218
# KULIYAPITIYA      21
# PUTTALAM           8
# NIKAWERATIYA       7
# DAMBADENIYA        5
# GALGAMUWA          3
# COMPONENTII        1
# Name: Town, dtype: int64

# %%
dfMED_REGION02 = df[df['Region'] == 'MED-REGION02']
dfMED_REGION02.Town.value_counts().to_csv('2.csv')
# Out:
# /home/ranulal/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.

# %%
dfMED_REGION06 = df[df['Region'] == 'MED-REGION06']
dfMED_REGION06.Town.value_counts()
# Out:
# BADULLA                 614
# BATTICALOA              303
# AMPARA                  264
# TRINCOMALEE             254
# MONARAGALA              196
# KALMUNAI                175
# AKKARAIPATTU            157
# KANTHALE                135
# DIYATALAWA              105
# MAHIYANGANAYA           105
# EASTERNPROVINCE          40
# UVAPROVINCIALCOUNCIL     28
# Name: Town, dtype: int64

# %%
dfMED_REGION03 = df[df['Region'] == 'MED-REGION03']
dfMED_REGION03.Town.value_counts()
# Out:
# COLOMBONORTH                            421
# GAMPAHA                                 357
# NEGOMBO                                 297
# WATHUPITIWALA                           238
# WELISARA                                177
# COLOMBO                                  82
# COLOMBO10                                75
# COLOMBO08                                67
# SEEDUWA                                  38
# KELANIYADIRECTORATEOFORDNANCESERVICE     13
# COLOMBO03                                12
# RATHMALANA                               12
# COLOMBO09                                 6
# COLOMBO07                                 6
# COMPONENTII                               5
# NARAHENPITA                               4
# MEDICINE                                  3
# WESTERNPROVINCE                           3
# FACULTYOFMEDICINE                         2
# EPIDEMIOLOGYUNIT                          2
# LEPROSYCAMPAIGN-MOH                       1
# ...

# %%
dfMED_REGION09 = df[df['Region'] == 'MED-REGION09']
dfMED_REGION09.Town.value_counts()
# Out:
# COLOMBOSOUTH                         574
# NUGEGODA                             565
# MAHARAGAMA                           194
# COLOMBO04                            165
# MEDICINE                              26
# POSTGRADUATEMEDICALTRAININGCENTER     13
# PHYSIOLOGY                            11
# NARAHENPITA                            7
# COLOMBO01                              6
# FAMILYPRACTICECENTER                   3
# SRILANKA                               3
# FAMILYMEDICINE                         2
# DEPARTMENTOFPAEDIATRICS-NUGEGODA       2
# BIOCHEMISTRY                           1
# Name: Town, dtype: int64

# %%
dfMED_REGION07 = df[df['Region'] == 'MED-REGION07']
dfMED_REGION07.Town.value_counts()
# Out:
# JAFFNA              463
# KILINOCHCHI         176
# VAVUNIYA            141
# MANNAR               97
# MULATHIW             17
# NORTHERNPROVINCE     12
# Name: Town, dtype: int64

# %%
dfMED_REGION11 = df[df['Region'] == 'MED-REGION11']
dfMED_REGION11.Town.value_counts()
# Out:
# KALUTARA    350
# HORANA      201
# PANADURA    148
# PIMBURA       5
# Name: Town, dtype: int64

# %%
dfMED_REGION08 = df[df['Region'] == 'MED-REGION08']
dfMED_REGION08.Town.value_counts()
# Out:
# HOMAGAMA           215
# ANGODA              81
# COLOMBO10           80
# AVISSAWELLA         72
# MULLERIYAWA         51
# WESTERNPROVINCE     37
# Name: Town, dtype: int64

# %%
dfMED_REGION00 = df[df['Region'] == 'REGION00']
dfMED_REGION00.Town.value_counts()
# Out:
# COLOMBO10               34
# JAFFNA                  21
# KARAPITIYA              18
# BADULLA                 17
# KILINOCHCHI              6
# KANDY                    6
# MAHARAGAMA               5
# ANURADHAPURA             5
# POLONNARUWA              4
# MONARAGALA               4
# FACULTYOFMEDICINE        3
# NORTHCENTRALPROVINC,     3
# COLOMBONORTH             3
# NARAHENPITA              3
# MOUNTLAVINIA             3
# RATHNAPURA               3
# ALLIEDHEALTHSCIENCE      2
# COLOMBO07                2
# HEALTHCENTRE             2
# MANNAR                   2
# MEDICALCENTER            1
# AMPARA                   1
# SOUTHERNPROVINCE         1
# NUGEGODA                 1
# PERADENIYA               1
# CHILAW                   1
# COLOMBOSOUTH             1
# Name: Town, dtype: int64
